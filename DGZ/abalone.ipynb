# %% [markdown]
# # Abalone

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
column_names = ['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight', 'Viscera_weight',
                'Shell_weight', 'Rings']
df = pd.read_csv("./dataset/abalone/abalone.data", sep=",", header=None, names=column_names)
df
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera_weight  Shell_weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole_weight    4177 non-null   float64
#  5   Shucked_weight  4177 non-null   float64
#  6   Viscera_weight  4177 non-null   float64
#  7   Shell_weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
# df = pd.get_dummies(df, columns=['Sex'], prefix='Sex')
# df[['Sex_F', 'Sex_M', 'Sex_I']] = df[['Sex_F', 'Sex_M', 'Sex_I']].astype(int)
# 
# df

# %%
df = df.drop(columns=['Sex'])
df
# Out:
#       Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell_weight  Rings
# ...

# %%
df['Age'] = df['Rings'] + 1.5
df = df.drop(columns=['Rings'])

df
# Out:
#       Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell_weight   Age
# ...

# %%
for column in df.columns:
    plt.figure(figsize=(6, 4))
    plt.boxplot(df[column], vert=False)
    plt.title(f'Box Plot for {column}')
    plt.xlabel(column)
    plt.show()

# %%
sns.pairplot(df)

# %%
correlation_matrix = df.drop(columns=['Age']).corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1, square=True)
plt.title("Correlation Matrix (Excluding Age)")
plt.show()

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.svm import SVR

param_distributions = {
    'C': [0.1, 1, 10, 100],
    'epsilon': [0.01, 0.1, 0.2, 0.5, 1],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'gamma': ['scale', 'auto']
}

svr_model = SVR()

random_search = RandomizedSearchCV(
    svr_model,
    param_distributions=param_distributions,
    n_iter=20,
    cv=5,
    scoring='neg_mean_squared_error',
    random_state=0,
    n_jobs=-1
)

random_search.fit(X_train, y_train)

best_params = random_search.best_params_
best_score = -random_search.best_score_

print("Best parameters found: ", best_params)
print("Best cross-validation accuracy: ", best_score)
# Out:
# Best parameters found:  {'kernel': 'rbf', 'gamma': 'scale', 'epsilon': 0.5, 'C': 100}
# Best cross-validation accuracy:  4.5604277768703705

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

svr_model = SVR(kernel='rbf', gamma='scale', C=100, epsilon=0.5)
svr_model.fit(X_train, y_train)

y_pred = svr_model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MSE: {mse:.2f}")
print(f"MAE: {mae:.2f}")
print(f"R²: {r2:.2f}")
# Out:
# MSE: 4.61
# MAE: 1.49
# R²: 0.58

# %%
from sklearn.model_selection import cross_val_score

# K-fold CV (K=5)
mse_scores = -cross_val_score(svr_model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
r2_scores = cross_val_score(svr_model, X_train, y_train, cv=5, scoring='r2')

print(f"Mean MSE: {mse_scores.mean():.2f}")
print(f"MSE Standard Deviation: {mse_scores.std():.2f}")
print("\n")
print(f"Mean R² Score: {r2_scores.mean():.2f}")
print(f"R² Score Standard Deviation: {r2_scores.std():.2f}")
# Out:
# Mean MSE: 4.56
# MSE Standard Deviation: 0.33
#
#
# Mean R² Score: 0.56
# R² Score Standard Deviation: 0.02

# %%
plt.figure(figsize=(14, 6))

# MSE
plt.subplot(1, 2, 1)
plt.plot(range(1, 6), mse_scores, marker='o', linestyle='-', color='b', label='MSE per Fold')
plt.axhline(y=mse_scores.mean(), color='r', linestyle='--', label=f'Mean MSE: {mse_scores.mean():.2f}')
plt.title('MSE Scores Across 10 Folds')
plt.xlabel('Fold')
plt.ylabel('MSE')
plt.ylim([0, 10])
plt.legend()
plt.grid(True)

# R2
plt.subplot(1, 2, 2)
plt.plot(range(1, 6), r2_scores, marker='o', linestyle='-', color='g', label='R² per Fold')
plt.axhline(y=r2_scores.mean(), color='r', linestyle='--', label=f'Mean R²: {r2_scores.mean():.2f}')
plt.title('R² Scores Across 10 Folds')
plt.xlabel('Fold')
plt.ylabel('R²')
plt.ylim([0, 1])
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
